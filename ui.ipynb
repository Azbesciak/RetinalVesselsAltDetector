# %%
from jupyter_backend import *
# %matplotlib inline


widgets.VBox([
    widgets.HBox([image_select, manual_select, mask_select]),
    widgets.HBox([show_images_btn, run_img_proc_btn, run_network_btn]),
])
# Out:
# C:\Users\Witek\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# curses is not supported on this machine (please install/reinstall curses for an optimal experience)
# ...
# selected 01_dr.JPG
# selected 01_dr.tif
# selected 01_dr_mask.tif
# ## image processing result
# | Measure | Value |
# | --- | --- |
# | Accuracy |0.9201313241345921|
# | Error level |0.0798686758654079|
# | Sensitivity | 0.8417594064652888 |
# | Specificity | 0.9240467453522051 |
# | Positive Predictive Value | 0.35636722606120436 |
# | Negative Predictive Value | 0.9915171418506608 |
# | Medium Square Error | 0.04652527454103445
# | Positive to negative value in original | 0.049959492303537675 |
# | Accuracy(Norm) | 0.882903075908747 |
# ...
